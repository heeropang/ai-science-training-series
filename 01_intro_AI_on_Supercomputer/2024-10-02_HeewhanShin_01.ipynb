# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import IPython.display as ipydis
import time
import pylab as p
! [ -e ./slimmed_realestate_data.csv ] || wget https://raw.githubusercontent.com/argonne-lcf/ai-science-training-series/main/01_intro_AI_on_Supercomputer/slimmed_realestate_data.csv
data=pd.read_csv('slimmed_realestate_data.csv')

n=len(data)
x=data['GrLivArea'].to_numpy()
y=data['SalePrice'].to_numpy()

sum_xy=np.sum(x*y)
sum_x=np.sum(x)
sum_y=np.sum(y)
sum_x2=np.sum(x*x)
denominator= n*sum_x2 - sum_x * sum_x

m=(n*sum_xy - sum_x * sum_y) /denominator
b=(sum_y * sum_x2 - sum_x * sum_xy) /denominator
m_calc=m
b_calc=b

def plot_data(x,y,m,b,plt=plt):
    plt.plot(x,y,'bo')
    linear_x=np.arange(x.min(), x.max())
    linear_y=linear_x*m+b
    plt.plot(linear_x,linear_y,'r-', label='fit')

def model(x,m,b):
    return m*x+b

def loss(x,y,m,b):
    y_predicted=model(x,m,b)
    return np.power(y-y_predicted,2)

def updated_m(x,y,m,b,learning_rate):
    dL_dm=-2*x*(y-model(x,m,b))
    dL_dm=np.mean(dL_dm)
    return m-learning_rate*dL_dm

def updated_b(x,y,m,b,learning_rate):
    dL_db=-2*(y-model(x,m,b))
    dL_db=np.mean(dL_db)
    return b-learning_rate*dL_db

learning_rate=1e-9
m=updated_m(x,y,m,b,learning_rate)
b=updated_b(x,y,m,b,learning_rate)
#print('y_i=%.2f*x+%.2f previously calculated: y_i=%.2f*x+%.2f'%(m,b,m_calc,b_calc))

m = 5.
b = 1000.
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []

batch_sizes=[32,64,128,256,512]
initial_m=5
initial_b=1000

for batch_size in batch_sizes:
    m=initial_m
    b=initial_b
    data_batch=data.sample(batch_size)
    data_x = data_batch['GrLivArea'].to_numpy()
    data_y = data_batch['SalePrice'].to_numpy()
    loss_history=[]
    loop_N = 30*len(data)//batch_size
    for i in range(loop_N):
        # update our slope and intercept based on the current values
        m = updated_m(data_x,data_y,m,b,learning_rate_m)
        b = updated_b(data_x,data_y,m,b,learning_rate_b)

        # calculate the loss value
        loss_value = np.mean(loss(data_x,data_y,m,b))

        # keep a history of our loss values
        loss_history.append(loss_value)

        # print our progress
        print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))

        # close/delete previous plots
        plt.close('all')

        # create a 1 by 2 plot grid
        fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
        #plot our usual output
        plot_data(data_x,data_y,m,b,ax[0])

        # here we also plot the calculated linear fit for comparison
        line_x = np.arange(data_x.min(),data_x.max())
        line_y = line_x * m_calc + b_calc
        ax[0].plot(line_x,line_y,'b-',label='calculated')
        # add a legend to the plot and x/y labels
        ax[0].legend()
        ax[0].set_xlabel('square footage')
        ax[0].set_ylabel('sale price')

        # plot the loss
        loss_x = np.arange(0,len(loss_history))
        loss_y = np.asarray(loss_history)
        ax[1].plot(loss_x,loss_y, 'o-')
        ax[1].set_yscale('log')
        ax[1].set_xlabel('loop step')
        ax[1].set_ylabel('loss')
    fig.suptitle(f"batch size = {batch_size}", fontsize=16)
    plt.show()
    time.sleep(2.5)
# Out:
# --2024-10-06 07:13:12--  https://raw.githubusercontent.com/argonne-lcf/ai-science-training-series/main/01_intro_AI_on_Supercomputer/slimmed_realestate_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8804 (8.6K) [text/plain]
# Saving to: ‘slimmed_realestate_data.csv’
#
# slimmed_realestate_ 100%[===================>]   8.60K  --.-KB/s    in 0s
#
# 2024-10-06 07:13:13 (70.8 MB/s) - ‘slimmed_realestate_data.csv’ saved [8804/8804]
#
# [000]  dy_i = 52.50 * x + 18000.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 5826158996.991856
# [001]  dy_i = 73.91 * x + 25533.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1758303708.075760
# [002]  dy_i = 83.60 * x + 28813.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 933262912.897367
# [003]  dy_i = 88.01 * x + 30185.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 764787230.361451
# [004]  dy_i = 90.07 * x + 30701.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 729739743.181842
# [005]  dy_i = 91.05 * x + 30834.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 722030459.947891
# [006]  dy_i = 91.56 * x + 30797.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 720024810.994167
# [007]  dy_i = 91.85 * x + 30685.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 719258039.701640
# [008]  dy_i = 92.04 * x + 30541.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 718785475.951405
# [009]  dy_i = 92.19 * x + 30385.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 718397047.704714
# [010]  dy_i = 92.31 * x + 30224.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 718041609.543350
# [011]  dy_i = 92.43 * x + 30062.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 717704806.804089
# [012]  dy_i = 92.54 * x + 29902.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 717381798.247779
# [013]  dy_i = 92.64 * x + 29744.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 717070590.414042
# [014]  dy_i = 92.75 * x + 29589.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 716770179.628028
# [015]  dy_i = 92.85 * x + 29436.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 716479950.373618
# [016]  dy_i = 92.95 * x + 29285.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 716199453.591043
# [017]  dy_i = 93.04 * x + 29137.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 715928317.472907
# [018]  dy_i = 93.14 * x + 28991.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 715666209.664354
# [019]  dy_i = 93.23 * x + 28848.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 715412820.737367
# [020]  dy_i = 93.33 * x + 28707.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 715167856.778430
# [021]  dy_i = 93.42 * x + 28569.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 714931035.949408
# [022]  dy_i = 93.51 * x + 28433.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 714702086.797680
# [023]  dy_i = 93.59 * x + 28299.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 714480747.342356
# [024]  dy_i = 93.68 * x + 28167.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 714266764.508408
# [025]  dy_i = 93.77 * x + 28038.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 714059893.719803
# [026]  dy_i = 93.85 * x + 27911.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 713859898.568048
# [027]  dy_i = 93.93 * x + 27785.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 713666550.519104
# [028]  dy_i = 94.01 * x + 27662.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 713479628.642109
# [029]  dy_i = 94.09 * x + 27542.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 713298919.352460
# [030]  dy_i = 94.17 * x + 27423.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 713124216.165783
# [031]  dy_i = 94.25 * x + 27306.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712955319.461125
# [032]  dy_i = 94.32 * x + 27191.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712792036.252476
# [033]  dy_i = 94.40 * x + 27078.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712634179.968089
# [034]  dy_i = 94.47 * x + 26967.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712481570.237220
# [035]  dy_i = 94.54 * x + 26857.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712334032.684000
# [036]  dy_i = 94.61 * x + 26750.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712191398.728174
# [037]  dy_i = 94.68 * x + 26644.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 712053505.392470
# [038]  dy_i = 94.75 * x + 26540.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711920195.116374
# [039]  dy_i = 94.82 * x + 26438.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711791315.576096
# [040]  dy_i = 94.88 * x + 26338.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711666719.510523
# [041]  dy_i = 94.95 * x + 26239.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711546264.552946
# [042]  dy_i = 95.01 * x + 26142.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711429813.068400
# [043]  dy_i = 95.08 * x + 26047.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711317231.996389
# [044]  dy_i = 95.14 * x + 25953.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711208392.698852
# [045]  dy_i = 95.20 * x + 25860.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711103170.813176
# [046]  dy_i = 95.26 * x + 25770.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 711001446.110098
# [047]  dy_i = 95.32 * x + 25680.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710903102.356327
# [048]  dy_i = 95.37 * x + 25593.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710808027.181731
# [049]  dy_i = 95.43 * x + 25506.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710716111.950943
# [050]  dy_i = 95.49 * x + 25422.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710627251.639229
# [051]  dy_i = 95.54 * x + 25338.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710541344.712486
# [052]  dy_i = 95.60 * x + 25256.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710458293.011226
# [053]  dy_i = 95.65 * x + 25176.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710378001.638413
# [054]  dy_i = 95.70 * x + 25096.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710300378.851038
# [055]  dy_i = 95.75 * x + 25018.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710225335.955283
# [056]  dy_i = 95.80 * x + 24942.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710152787.205185
# [057]  dy_i = 95.85 * x + 24866.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710082649.704655
# [058]  dy_i = 95.90 * x + 24792.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 710014843.312761
# [059]  dy_i = 95.95 * x + 24720.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709949290.552154
# [060]  dy_i = 96.00 * x + 24648.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709885916.520546
# [061]  dy_i = 96.04 * x + 24578.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709824648.805121
# [062]  dy_i = 96.09 * x + 24508.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709765417.399792
# [063]  dy_i = 96.13 * x + 24440.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709708154.625216
# [064]  dy_i = 96.18 * x + 24373.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709652795.051456
# [065]  dy_i = 96.22 * x + 24307.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709599275.423224
# [066]  dy_i = 96.26 * x + 24243.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709547534.587602
# [067]  dy_i = 96.30 * x + 24179.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709497513.424163
# [068]  dy_i = 96.34 * x + 24117.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709449154.777425
# [069]  dy_i = 96.39 * x + 24055.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709402403.391541
# [070]  dy_i = 96.43 * x + 23995.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709357205.847163
# [071]  dy_i = 96.46 * x + 23935.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709313510.500399
# [072]  dy_i = 96.50 * x + 23877.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709271267.423809
# [073]  dy_i = 96.54 * x + 23819.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709230428.349357
# [074]  dy_i = 96.58 * x + 23763.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709190946.613252
# [075]  dy_i = 96.61 * x + 23707.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709152777.102638
# [076]  dy_i = 96.65 * x + 23652.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709115876.204037
# [077]  dy_i = 96.69 * x + 23599.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709080201.753524
# [078]  dy_i = 96.72 * x + 23546.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709045712.988543
# [079]  dy_i = 96.75 * x + 23494.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 709012370.501334
# [080]  dy_i = 96.79 * x + 23443.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708980136.193904
# [081]  dy_i = 96.82 * x + 23393.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708948973.234496
# [082]  dy_i = 96.85 * x + 23343.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708918846.015501
# [083]  dy_i = 96.89 * x + 23295.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708889720.112775
# [084]  dy_i = 96.92 * x + 23247.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708861562.246304
# [085]  dy_i = 96.95 * x + 23200.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708834340.242178
# [086]  dy_i = 96.98 * x + 23154.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708808022.995826
# [087]  dy_i = 97.01 * x + 23108.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708782580.436479
# [088]  dy_i = 97.04 * x + 23064.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708757983.492805
# [089]  dy_i = 97.07 * x + 23020.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708734204.059699
# [090]  dy_i = 97.09 * x + 22977.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708711214.966159
# [091]  dy_i = 97.12 * x + 22934.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708688989.944252
# [092]  dy_i = 97.15 * x + 22893.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708667503.599089
# [093]  dy_i = 97.18 * x + 22852.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708646731.379811
# [094]  dy_i = 97.20 * x + 22811.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708626649.551543
# [095]  dy_i = 97.23 * x + 22772.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708607235.168263
# [096]  dy_i = 97.25 * x + 22733.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708588466.046594
# [097]  dy_i = 97.28 * x + 22694.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708570320.740448
# [098]  dy_i = 97.30 * x + 22657.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708552778.516527
# [099]  dy_i = 97.33 * x + 22620.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708535819.330628
# [100]  dy_i = 97.35 * x + 22583.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708519423.804747
# [101]  dy_i = 97.38 * x + 22547.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708503573.204927
# [102]  dy_i = 97.40 * x + 22512.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708488249.419862
# [103]  dy_i = 97.42 * x + 22478.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708473434.940195
# [104]  dy_i = 97.44 * x + 22444.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708459112.838518
# [105]  dy_i = 97.47 * x + 22410.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708445266.750024
# [106]  dy_i = 97.49 * x + 22377.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708431880.853813
# [107]  dy_i = 97.51 * x + 22345.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708418939.854810
# [108]  dy_i = 97.53 * x + 22313.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708406428.966295
# [109]  dy_i = 97.55 * x + 22282.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708394333.893001
# [110]  dy_i = 97.57 * x + 22251.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708382640.814782
# [111]  dy_i = 97.59 * x + 22221.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708371336.370822
# [112]  dy_i = 97.61 * x + 22191.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708360407.644371
# [113]  dy_i = 97.63 * x + 22162.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708349842.147981
# [114]  dy_i = 97.65 * x + 22133.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708339627.809241
# [115]  dy_i = 97.67 * x + 22105.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708329752.956982
# [116]  dy_i = 97.69 * x + 22077.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708320206.307941
# [117]  dy_i = 97.70 * x + 22050.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708310976.953869
# [118]  dy_i = 97.72 * x + 22023.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708302054.349065
# [119]  dy_i = 97.74 * x + 21996.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708293428.298328
# [120]  dy_i = 97.76 * x + 21970.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708285088.945311
# [121]  dy_i = 97.77 * x + 21945.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708277026.761249
# [122]  dy_i = 97.79 * x + 21920.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708269232.534083
# [123]  dy_i = 97.81 * x + 21895.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708261697.357926
# [124]  dy_i = 97.82 * x + 21871.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708254412.622889
# [125]  dy_i = 97.84 * x + 21847.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708247370.005244
# [126]  dy_i = 97.85 * x + 21823.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708240561.457914
# [127]  dy_i = 97.87 * x + 21800.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708233979.201275
# [128]  dy_i = 97.88 * x + 21777.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708227615.714270
# [129]  dy_i = 97.90 * x + 21755.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708221463.725812
# [130]  dy_i = 97.91 * x + 21733.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708215516.206481
# [131]  dy_i = 97.93 * x + 21712.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708209766.360484
# [132]  dy_i = 97.94 * x + 21690.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708204207.617900
# [133]  dy_i = 97.95 * x + 21670.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708198833.627163
# [134]  dy_i = 97.97 * x + 21649.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708193638.247814
# [135]  dy_i = 97.98 * x + 21629.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708188615.543475
# [136]  dy_i = 97.99 * x + 21609.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708183759.775074
# [137]  dy_i = 98.01 * x + 21590.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708179065.394284
# [138]  dy_i = 98.02 * x + 21570.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708174527.037184
# [139]  dy_i = 98.03 * x + 21552.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708170139.518128
# [140]  dy_i = 98.04 * x + 21533.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708165897.823823
# [141]  dy_i = 98.06 * x + 21515.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708161797.107599
# [142]  dy_i = 98.07 * x + 21497.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708157832.683871
# [143]  dy_i = 98.08 * x + 21479.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708154000.022786
# [144]  dy_i = 98.09 * x + 21462.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708150294.745044
# [145]  dy_i = 98.10 * x + 21445.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708146712.616899
# [146]  dy_i = 98.11 * x + 21428.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708143249.545319
# [147]  dy_i = 98.12 * x + 21412.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708139901.573307
# [148]  dy_i = 98.13 * x + 21396.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708136664.875385
# [149]  dy_i = 98.14 * x + 21380.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708133535.753216
# [150]  dy_i = 98.15 * x + 21364.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708130510.631384
# [151]  dy_i = 98.16 * x + 21349.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708127586.053307
# [152]  dy_i = 98.17 * x + 21334.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708124758.677284
# [153]  dy_i = 98.18 * x + 21319.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708122025.272684
# [154]  dy_i = 98.19 * x + 21304.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708119382.716247
# [155]  dy_i = 98.20 * x + 21290.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708116827.988519
# [156]  dy_i = 98.21 * x + 21275.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708114358.170402
# [157]  dy_i = 98.22 * x + 21262.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708111970.439817
# [158]  dy_i = 98.23 * x + 21248.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708109662.068481
# [159]  dy_i = 98.24 * x + 21234.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708107430.418789
# [160]  dy_i = 98.25 * x + 21221.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708105272.940801
# [161]  dy_i = 98.26 * x + 21208.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708103187.169325
# [162]  dy_i = 98.27 * x + 21195.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708101170.721105
# [163]  dy_i = 98.27 * x + 21183.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708099221.292094
# [164]  dy_i = 98.28 * x + 21171.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708097336.654825
# [165]  dy_i = 98.29 * x + 21158.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708095514.655863
# [166]  dy_i = 98.30 * x + 21147.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708093753.213342
# [167]  dy_i = 98.31 * x + 21135.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708092050.314594
# [168]  dy_i = 98.31 * x + 21123.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708090404.013842
# [169]  dy_i = 98.32 * x + 21112.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708088812.429980
# [170]  dy_i = 98.33 * x + 21101.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708087273.744423
# [171]  dy_i = 98.33 * x + 21090.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708085786.199028
# [172]  dy_i = 98.34 * x + 21079.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708084348.094088
# [173]  dy_i = 98.35 * x + 21068.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708082957.786387
# [174]  dy_i = 98.36 * x + 21058.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708081613.687323
# [175]  dy_i = 98.36 * x + 21048.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708080314.261093
# [176]  dy_i = 98.37 * x + 21038.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708079058.022938
# [177]  dy_i = 98.38 * x + 21028.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708077843.537450
# [178]  dy_i = 98.38 * x + 21018.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708076669.416924
# [179]  dy_i = 98.39 * x + 21008.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708075534.319781
# [180]  dy_i = 98.39 * x + 20999.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708074436.949028
# [181]  dy_i = 98.40 * x + 20990.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708073376.050782
# [182]  dy_i = 98.41 * x + 20981.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708072350.412832
# [183]  dy_i = 98.41 * x + 20972.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708071358.863259
# [184]  dy_i = 98.42 * x + 20963.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708070400.269091
# [185]  dy_i = 98.42 * x + 20954.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708069473.535013
# [186]  dy_i = 98.43 * x + 20946.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708068577.602117
# [187]  dy_i = 98.44 * x + 20937.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708067711.446684
# [188]  dy_i = 98.44 * x + 20929.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708066874.079024
# [189]  dy_i = 98.45 * x + 20921.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708066064.542338
# [190]  dy_i = 98.45 * x + 20913.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708065281.911629
# [191]  dy_i = 98.46 * x + 20905.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708064525.292642
# [192]  dy_i = 98.46 * x + 20897.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708063793.820846
# [193]  dy_i = 98.47 * x + 20890.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708063086.660441
# [194]  dy_i = 98.47 * x + 20882.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708062403.003407
# [195]  dy_i = 98.48 * x + 20875.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708061742.068581
# [196]  dy_i = 98.48 * x + 20868.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708061103.100760
# [197]  dy_i = 98.49 * x + 20861.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708060485.369844
# [198]  dy_i = 98.49 * x + 20854.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708059888.169997
# [199]  dy_i = 98.49 * x + 20847.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708059310.818843
# [200]  dy_i = 98.50 * x + 20840.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708058752.656685
# [201]  dy_i = 98.50 * x + 20834.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708058213.045754
# [202]  dy_i = 98.51 * x + 20827.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708057691.369476
# [203]  dy_i = 98.51 * x + 20821.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708057187.031768
# [204]  dy_i = 98.52 * x + 20815.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708056699.456363
# [205]  dy_i = 98.52 * x + 20808.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708056228.086144
# [206]  dy_i = 98.52 * x + 20802.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708055772.382512
# [207]  dy_i = 98.53 * x + 20796.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708055331.824766
# [208]  dy_i = 98.53 * x + 20790.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708054905.909515
# [209]  dy_i = 98.54 * x + 20785.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708054494.150096
# [210]  dy_i = 98.54 * x + 20779.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708054096.076023
# [211]  dy_i = 98.54 * x + 20773.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708053711.232446
# [212]  dy_i = 98.55 * x + 20768.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708053339.179633
# [213]  dy_i = 98.55 * x + 20763.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708052979.492466
# [214]  dy_i = 98.55 * x + 20757.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708052631.759957
# [215]  dy_i = 98.56 * x + 20752.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708052295.584779
# [216]  dy_i = 98.56 * x + 20747.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708051970.582808
# [217]  dy_i = 98.56 * x + 20742.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708051656.382689
# [218]  dy_i = 98.57 * x + 20737.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708051352.625409
# [219]  dy_i = 98.57 * x + 20732.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708051058.963886
# [220]  dy_i = 98.57 * x + 20727.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708050775.062577
# [221]  dy_i = 98.58 * x + 20722.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708050500.597087
# [222]  dy_i = 98.58 * x + 20718.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708050235.253804
# [223]  dy_i = 98.58 * x + 20713.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708049978.729542
# [224]  dy_i = 98.59 * x + 20709.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708049730.731189
# [225]  dy_i = 98.59 * x + 20704.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708049490.975374
# [226]  dy_i = 98.59 * x + 20700.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708049259.188148
# [227]  dy_i = 98.59 * x + 20696.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708049035.104664
# [228]  dy_i = 98.60 * x + 20692.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708048818.468878
# [229]  dy_i = 98.60 * x + 20688.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708048609.033257
# [230]  dy_i = 98.60 * x + 20683.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708048406.558494
# [231]  dy_i = 98.60 * x + 20679.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708048210.813235
# [232]  dy_i = 98.61 * x + 20676.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708048021.573819
# [233]  dy_i = 98.61 * x + 20672.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708047838.624014
# [234]  dy_i = 98.61 * x + 20668.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708047661.754777
# [235]  dy_i = 98.61 * x + 20664.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708047490.764014
# [236]  dy_i = 98.62 * x + 20661.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708047325.456345
# [237]  dy_i = 98.62 * x + 20657.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708047165.642885
# [238]  dy_i = 98.62 * x + 20653.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708047011.141029
# [239]  dy_i = 98.62 * x + 20650.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046861.774237
# [240]  dy_i = 98.63 * x + 20647.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046717.371840
# [241]  dy_i = 98.63 * x + 20643.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046577.768839
# [242]  dy_i = 98.63 * x + 20640.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046442.805720
# [243]  dy_i = 98.63 * x + 20637.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046312.328272
# [244]  dy_i = 98.64 * x + 20633.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046186.187407
# [245]  dy_i = 98.64 * x + 20630.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708046064.238993
# [246]  dy_i = 98.64 * x + 20627.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045946.343689
# [247]  dy_i = 98.64 * x + 20624.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045832.366785
# [248]  dy_i = 98.64 * x + 20621.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045722.178048
# [249]  dy_i = 98.65 * x + 20618.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045615.651573
# [250]  dy_i = 98.65 * x + 20615.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045512.665640
# [251]  dy_i = 98.65 * x + 20613.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045413.102575
# [252]  dy_i = 98.65 * x + 20610.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045316.848615
# [253]  dy_i = 98.65 * x + 20607.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045223.793777
# [254]  dy_i = 98.65 * x + 20604.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045133.831733
# [255]  dy_i = 98.66 * x + 20602.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708045046.859693
# [256]  dy_i = 98.66 * x + 20599.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044962.778278
# [257]  dy_i = 98.66 * x + 20596.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044881.491416
# [258]  dy_i = 98.66 * x + 20594.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044802.906226
# [259]  dy_i = 98.66 * x + 20591.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044726.932913
# [260]  dy_i = 98.66 * x + 20589.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044653.484670
# [261]  dy_i = 98.67 * x + 20587.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044582.477573
# [262]  dy_i = 98.67 * x + 20584.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044513.830486
# [263]  dy_i = 98.67 * x + 20582.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044447.464972
# [264]  dy_i = 98.67 * x + 20580.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044383.305200
# [265]  dy_i = 98.67 * x + 20577.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044321.277859
# [266]  dy_i = 98.67 * x + 20575.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044261.312075
# [267]  dy_i = 98.67 * x + 20573.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044203.339331
# [268]  dy_i = 98.68 * x + 20571.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044147.293383
# [269]  dy_i = 98.68 * x + 20569.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044093.110194
# [270]  dy_i = 98.68 * x + 20567.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708044040.727852
# [271]  dy_i = 98.68 * x + 20565.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043990.086503
# [272]  dy_i = 98.68 * x + 20563.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043941.128283
# [273]  dy_i = 98.68 * x + 20561.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043893.797252
# [274]  dy_i = 98.68 * x + 20559.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043848.039328
# [275]  dy_i = 98.69 * x + 20557.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043803.802226
# [276]  dy_i = 98.69 * x + 20555.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043761.035400
# [277]  dy_i = 98.69 * x + 20553.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043719.689984
# [278]  dy_i = 98.69 * x + 20551.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043679.718735
# [279]  dy_i = 98.69 * x + 20550.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043641.075982
# [280]  dy_i = 98.69 * x + 20548.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043603.717569
# [281]  dy_i = 98.69 * x + 20546.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043567.600810
# [282]  dy_i = 98.69 * x + 20545.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043532.684437
# [283]  dy_i = 98.69 * x + 20543.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043498.928554
# [284]  dy_i = 98.70 * x + 20541.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043466.294591
# [285]  dy_i = 98.70 * x + 20540.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043434.745259
# [286]  dy_i = 98.70 * x + 20538.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043404.244509
# [287]  dy_i = 98.70 * x + 20537.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043374.757489
# [288]  dy_i = 98.70 * x + 20535.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043346.250509
# [289]  dy_i = 98.70 * x + 20534.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043318.690994
# [290]  dy_i = 98.70 * x + 20532.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043292.047454
# [291]  dy_i = 98.70 * x + 20531.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043266.289446
# [292]  dy_i = 98.70 * x + 20529.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043241.387538
# [293]  dy_i = 98.70 * x + 20528.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043217.313277
# [294]  dy_i = 98.71 * x + 20526.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043194.039154
# [295]  dy_i = 98.71 * x + 20525.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043171.538576
# [296]  dy_i = 98.71 * x + 20524.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043149.785833
# [297]  dy_i = 98.71 * x + 20523.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043128.756070
# [298]  dy_i = 98.71 * x + 20521.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043108.425258
# [299]  dy_i = 98.71 * x + 20520.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043088.770166
# [300]  dy_i = 98.71 * x + 20519.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043069.768337
# [301]  dy_i = 98.71 * x + 20518.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043051.398057
# [302]  dy_i = 98.71 * x + 20516.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043033.638336
# [303]  dy_i = 98.71 * x + 20515.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708043016.468882
# [304]  dy_i = 98.71 * x + 20514.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042999.870077
# [305]  dy_i = 98.71 * x + 20513.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042983.822954
# [306]  dy_i = 98.72 * x + 20512.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042968.309178
# [307]  dy_i = 98.72 * x + 20511.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042953.311022
# [308]  dy_i = 98.72 * x + 20510.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042938.811348
# [309]  dy_i = 98.72 * x + 20508.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042924.793589
# [310]  dy_i = 98.72 * x + 20507.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042911.241728
# [311]  dy_i = 98.72 * x + 20506.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042898.140281
# [312]  dy_i = 98.72 * x + 20505.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042885.474277
# [313]  dy_i = 98.72 * x + 20504.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042873.229243
# [314]  dy_i = 98.72 * x + 20503.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042861.391189
# [315]  dy_i = 98.72 * x + 20502.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042849.946587
# [316]  dy_i = 98.72 * x + 20501.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042838.882361
# [317]  dy_i = 98.72 * x + 20501.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042828.185869
# [318]  dy_i = 98.72 * x + 20500.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042817.844888
# [319]  dy_i = 98.72 * x + 20499.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042807.847603
# [320]  dy_i = 98.72 * x + 20498.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042798.182590
# [321]  dy_i = 98.72 * x + 20497.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042788.838806
# [322]  dy_i = 98.73 * x + 20496.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042779.805575
# [323]  dy_i = 98.73 * x + 20495.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042771.072574
# [324]  dy_i = 98.73 * x + 20494.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042762.629826
# [325]  dy_i = 98.73 * x + 20494.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042754.467683
# [326]  dy_i = 98.73 * x + 20493.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042746.576820
# [327]  dy_i = 98.73 * x + 20492.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042738.948219
# [328]  dy_i = 98.73 * x + 20491.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042731.573164
# [329]  dy_i = 98.73 * x + 20491.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042724.443229
# [330]  dy_i = 98.73 * x + 20490.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042717.550266
# [331]  dy_i = 98.73 * x + 20489.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042710.886400
# [332]  dy_i = 98.73 * x + 20488.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042704.444016
# [333]  dy_i = 98.73 * x + 20488.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042698.215752
# [334]  dy_i = 98.73 * x + 20487.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042692.194492
# [335]  dy_i = 98.73 * x + 20486.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042686.373357
# [336]  dy_i = 98.73 * x + 20486.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042680.745695
# [337]  dy_i = 98.73 * x + 20485.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042675.305075
# [338]  dy_i = 98.73 * x + 20484.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042670.045280
# [339]  dy_i = 98.73 * x + 20484.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042664.960303
# [340]  dy_i = 98.73 * x + 20483.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042660.044330
# [341]  dy_i = 98.73 * x + 20482.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042655.291746
# [342]  dy_i = 98.73 * x + 20482.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042650.697120
# [343]  dy_i = 98.74 * x + 20481.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042646.255203
# [344]  dy_i = 98.74 * x + 20481.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042641.960918
# [345]  dy_i = 98.74 * x + 20480.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042637.809359
# [346]  dy_i = 98.74 * x + 20479.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042633.795783
# [347]  dy_i = 98.74 * x + 20479.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042629.915603
# [348]  dy_i = 98.74 * x + 20478.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042626.164385
# [349]  dy_i = 98.74 * x + 20478.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042622.537844
# [350]  dy_i = 98.74 * x + 20477.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042619.031836
# [351]  dy_i = 98.74 * x + 20477.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042615.642354
# [352]  dy_i = 98.74 * x + 20476.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042612.365526
# [353]  dy_i = 98.74 * x + 20476.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042609.197608
# [354]  dy_i = 98.74 * x + 20475.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042606.134979
# [355]  dy_i = 98.74 * x + 20475.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042603.174140
# [356]  dy_i = 98.74 * x + 20474.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042600.311709
# [357]  dy_i = 98.74 * x + 20474.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042597.544415
# [358]  dy_i = 98.74 * x + 20473.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042594.869095
# [359]  dy_i = 98.74 * x + 20473.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042592.282692
# [360]  dy_i = 98.74 * x + 20472.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042589.782252
# [361]  dy_i = 98.74 * x + 20472.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042587.364918
# [362]  dy_i = 98.74 * x + 20471.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042585.027926
# [363]  dy_i = 98.74 * x + 20471.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042582.768607
# [364]  dy_i = 98.74 * x + 20471.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042580.584380
# [365]  dy_i = 98.74 * x + 20470.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042578.472748
# [366]  dy_i = 98.74 * x + 20470.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042576.431299
# [367]  dy_i = 98.74 * x + 20469.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042574.457700
# [368]  dy_i = 98.74 * x + 20469.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042572.549696
# [369]  dy_i = 98.74 * x + 20469.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042570.705107
# [370]  dy_i = 98.74 * x + 20468.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042568.921825
# [371]  dy_i = 98.74 * x + 20468.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042567.197814
# [372]  dy_i = 98.74 * x + 20468.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042565.531101
# [373]  dy_i = 98.74 * x + 20467.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042563.919784
# [374]  dy_i = 98.74 * x + 20467.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042562.362021
# [375]  dy_i = 98.74 * x + 20466.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042560.856032
# [376]  dy_i = 98.75 * x + 20466.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042559.400097
# [377]  dy_i = 98.75 * x + 20466.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042557.992552
# [378]  dy_i = 98.75 * x + 20465.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042556.631788
# [379]  dy_i = 98.75 * x + 20465.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042555.316251
# [380]  dy_i = 98.75 * x + 20465.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042554.044437
# [381]  dy_i = 98.75 * x + 20464.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042552.814894
# [382]  dy_i = 98.75 * x + 20464.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042551.626216
# [383]  dy_i = 98.75 * x + 20464.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042550.477046
# [384]  dy_i = 98.75 * x + 20464.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042549.366069
# [385]  dy_i = 98.75 * x + 20463.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042548.292017
# [386]  dy_i = 98.75 * x + 20463.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042547.253663
# [387]  dy_i = 98.75 * x + 20463.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042546.249820
# [388]  dy_i = 98.75 * x + 20462.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042545.279341
# [389]  dy_i = 98.75 * x + 20462.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042544.341116
# [390]  dy_i = 98.75 * x + 20462.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042543.434075
# [391]  dy_i = 98.75 * x + 20462.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042542.557181
# [392]  dy_i = 98.75 * x + 20461.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042541.709431
# [393]  dy_i = 98.75 * x + 20461.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042540.889858
# [394]  dy_i = 98.75 * x + 20461.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042540.097523
# [395]  dy_i = 98.75 * x + 20461.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042539.331524
# [396]  dy_i = 98.75 * x + 20460.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042538.590983
# [397]  dy_i = 98.75 * x + 20460.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042537.875054
# [398]  dy_i = 98.75 * x + 20460.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042537.182921
# [399]  dy_i = 98.75 * x + 20460.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042536.513792
# [400]  dy_i = 98.75 * x + 20459.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042535.866902
# [401]  dy_i = 98.75 * x + 20459.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042535.241512
# [402]  dy_i = 98.75 * x + 20459.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042534.636908
# [403]  dy_i = 98.75 * x + 20459.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042534.052398
# [404]  dy_i = 98.75 * x + 20459.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042533.487316
# [405]  dy_i = 98.75 * x + 20458.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042532.941014
# [406]  dy_i = 98.75 * x + 20458.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042532.412870
# [407]  dy_i = 98.75 * x + 20458.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042531.902279
# [408]  dy_i = 98.75 * x + 20458.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042531.408659
# [409]  dy_i = 98.75 * x + 20457.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042530.931444
# [410]  dy_i = 98.75 * x + 20457.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 708042530.470091
# ...
# [088]  dy_i = 96.41 * x + 25702.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211548126.520546
# [089]  dy_i = 96.44 * x + 25662.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211527016.116391
# [090]  dy_i = 96.47 * x + 25622.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211506658.262380
# [091]  dy_i = 96.49 * x + 25582.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211487026.131377
# [092]  dy_i = 96.52 * x + 25544.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211468093.852584
# [093]  dy_i = 96.55 * x + 25506.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211449836.477456
# [094]  dy_i = 96.57 * x + 25468.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211432229.946822
# [095]  dy_i = 96.60 * x + 25432.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211415251.059177
# [096]  dy_i = 96.62 * x + 25396.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211398877.440112
# [097]  dy_i = 96.64 * x + 25360.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211383087.512828
# [098]  dy_i = 96.67 * x + 25326.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211367860.469701
# [099]  dy_i = 96.69 * x + 25292.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211353176.244865
# [100]  dy_i = 96.71 * x + 25258.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211339015.487768
# [101]  dy_i = 96.74 * x + 25226.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211325359.537671
# [102]  dy_i = 96.76 * x + 25193.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211312190.399060
# [103]  dy_i = 96.78 * x + 25162.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211299490.717931
# [104]  dy_i = 96.80 * x + 25131.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211287243.758918
# [105]  dy_i = 96.82 * x + 25100.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211275433.383247
# [106]  dy_i = 96.84 * x + 25070.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211264044.027460
# [107]  dy_i = 96.86 * x + 25041.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211253060.682912
# [108]  dy_i = 96.88 * x + 25012.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211242468.875990
# [109]  dy_i = 96.90 * x + 24983.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211232254.649041
# [110]  dy_i = 96.92 * x + 24955.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211222404.541978
# [111]  dy_i = 96.94 * x + 24928.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211212905.574545
# [112]  dy_i = 96.96 * x + 24901.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211203745.229208
# [113]  dy_i = 96.98 * x + 24875.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211194911.434664
# [114]  dy_i = 96.99 * x + 24849.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211186392.549930
# [115]  dy_i = 97.01 * x + 24823.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211178177.349004
# [116]  dy_i = 97.03 * x + 24798.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211170255.006074
# [117]  dy_i = 97.04 * x + 24774.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211162615.081248
# [118]  dy_i = 97.06 * x + 24750.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211155247.506799
# [119]  dy_i = 97.08 * x + 24726.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211148142.573897
# [120]  dy_i = 97.09 * x + 24703.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211141290.919817
# [121]  dy_i = 97.11 * x + 24680.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211134683.515597
# [122]  dy_i = 97.12 * x + 24658.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211128311.654144
# [123]  dy_i = 97.14 * x + 24636.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211122166.938757
# [124]  dy_i = 97.15 * x + 24614.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211116241.272063
# [125]  dy_i = 97.17 * x + 24593.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211110526.845349
# [126]  dy_i = 97.18 * x + 24572.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211105016.128265
# [127]  dy_i = 97.20 * x + 24551.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211099701.858910
# [128]  dy_i = 97.21 * x + 24531.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1211094577.034254
# [000]  dy_i = 56.31 * x + 17413.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6538127872.186241
# [001]  dy_i = 78.09 * x + 24224.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2521109276.846077
# [002]  dy_i = 87.38 * x + 26978.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1797842151.360369
# [003]  dy_i = 91.39 * x + 28019.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1666238054.598771
# [004]  dy_i = 93.16 * x + 28338.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641519192.853590
# [005]  dy_i = 93.99 * x + 28353.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636366872.150608
# [006]  dy_i = 94.41 * x + 28244.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1634910273.357044
# [007]  dy_i = 94.66 * x + 28084.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1634205684.207750
# [008]  dy_i = 94.83 * x + 27905.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1633682710.077698
# [009]  dy_i = 94.98 * x + 27720.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1633220770.718622
# [010]  dy_i = 95.10 * x + 27535.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1632790234.260413
# [011]  dy_i = 95.22 * x + 27353.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1632382094.926058
# [012]  dy_i = 95.34 * x + 27173.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1631992855.668209
# [013]  dy_i = 95.45 * x + 26998.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1631620772.706025
# [014]  dy_i = 95.56 * x + 26826.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1631264748.010861
# [015]  dy_i = 95.67 * x + 26657.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1630923950.250757
# [016]  dy_i = 95.77 * x + 26492.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1630597671.518119
# [017]  dy_i = 95.87 * x + 26331.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1630285269.910858
# [018]  dy_i = 95.97 * x + 26173.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1629986145.570181
# [019]  dy_i = 96.07 * x + 26019.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1629699730.216088
# [020]  dy_i = 96.16 * x + 25867.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1629425482.228293
# [021]  dy_i = 96.25 * x + 25719.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1629162884.035679
# [022]  dy_i = 96.35 * x + 25575.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1628911440.483482
# [023]  dy_i = 96.43 * x + 25433.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1628670677.628226
# [024]  dy_i = 96.52 * x + 25294.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1628440141.732084
# [025]  dy_i = 96.61 * x + 25159.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1628219398.361293
# [026]  dy_i = 96.69 * x + 25026.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1628008031.548256
# [027]  dy_i = 96.77 * x + 24896.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1627805642.999734
# [028]  dy_i = 96.85 * x + 24769.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1627611851.343020
# [029]  dy_i = 96.93 * x + 24645.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1627426291.405933
# [030]  dy_i = 97.01 * x + 24523.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1627248613.528141
# [031]  dy_i = 97.08 * x + 24404.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1627078482.902043
# [032]  dy_i = 97.16 * x + 24288.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626915578.941777
# [033]  dy_i = 97.23 * x + 24174.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626759594.679085
# [034]  dy_i = 97.30 * x + 24062.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626610236.184859
# [035]  dy_i = 97.37 * x + 23953.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626467222.015270
# [036]  dy_i = 97.43 * x + 23846.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626330282.681424
# [037]  dy_i = 97.50 * x + 23741.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626199160.141553
# [038]  dy_i = 97.56 * x + 23639.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1626073607.314768
# [039]  dy_i = 97.63 * x + 23539.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625953387.615477
# [040]  dy_i = 97.69 * x + 23441.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625838274.507570
# [041]  dy_i = 97.75 * x + 23345.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625728051.077548
# [042]  dy_i = 97.81 * x + 23252.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625622509.625783
# [043]  dy_i = 97.86 * x + 23160.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625521451.275136
# [044]  dy_i = 97.92 * x + 23070.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625424685.596203
# [045]  dy_i = 97.98 * x + 22982.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625332030.248483
# [046]  dy_i = 98.03 * x + 22896.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625243310.636779
# [047]  dy_i = 98.08 * x + 22812.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625158359.582204
# [048]  dy_i = 98.14 * x + 22730.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625077017.007153
# [049]  dy_i = 98.19 * x + 22649.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624999129.633665
# [050]  dy_i = 98.24 * x + 22570.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624924550.694592
# [051]  dy_i = 98.28 * x + 22493.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624853139.657035
# [052]  dy_i = 98.33 * x + 22418.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624784761.957536
# [053]  dy_i = 98.38 * x + 22344.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624719288.748508
# [054]  dy_i = 98.42 * x + 22272.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624656596.655447
# [055]  dy_i = 98.47 * x + 22201.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624596567.544444
# [056]  dy_i = 98.51 * x + 22132.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624539088.299585
# [057]  dy_i = 98.55 * x + 22064.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624484050.609797
# [058]  dy_i = 98.60 * x + 21998.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624431350.764757
# [059]  dy_i = 98.64 * x + 21933.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624380889.459459
# [060]  dy_i = 98.68 * x + 21869.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624332571.607093
# [061]  dy_i = 98.72 * x + 21807.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624286306.159865
# [062]  dy_i = 98.75 * x + 21746.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624242005.937435
# [063]  dy_i = 98.79 * x + 21687.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1624199587.462634
# [000]  dy_i = 52.18 * x + 17816.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6329736860.336544
# [001]  dy_i = 73.14 * x + 25350.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2427509755.932057
# [002]  dy_i = 82.43 * x + 28754.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1657092061.911991
# [003]  dy_i = 86.52 * x + 30319.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1505346954.250718
# [004]  dy_i = 88.31 * x + 31065.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1475579557.265373
# [005]  dy_i = 89.08 * x + 31446.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1469758938.425408
# [006]  dy_i = 89.39 * x + 31664.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1468596160.516541
# [007]  dy_i = 89.49 * x + 31808.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1468321620.161824
# [008]  dy_i = 89.51 * x + 31918.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1468209867.553433
# [009]  dy_i = 89.49 * x + 32013.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1468126199.487210
# [010]  dy_i = 89.45 * x + 32099.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1468047753.757654
# [011]  dy_i = 89.41 * x + 32181.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467971600.265965
# [012]  dy_i = 89.36 * x + 32260.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467897797.468074
# [013]  dy_i = 89.31 * x + 32337.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467826581.055848
# [014]  dy_i = 89.26 * x + 32412.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467758043.482731
# [015]  dy_i = 89.21 * x + 32485.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467692173.227988
# [016]  dy_i = 89.17 * x + 32557.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467628907.230404
# [017]  dy_i = 89.12 * x + 32627.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467568160.648946
# [018]  dy_i = 89.08 * x + 32696.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467509841.123417
# [019]  dy_i = 89.03 * x + 32764.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467453855.171205
# [020]  dy_i = 88.99 * x + 32830.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467400110.940388
# [021]  dy_i = 88.95 * x + 32895.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467348519.334869
# [022]  dy_i = 88.91 * x + 32959.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467298994.424817
# [023]  dy_i = 88.87 * x + 33021.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467251453.547208
# [024]  dy_i = 88.83 * x + 33082.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467205817.274134
# [025]  dy_i = 88.79 * x + 33142.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467162009.326426
# [026]  dy_i = 88.75 * x + 33200.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467119956.466362
# [027]  dy_i = 88.71 * x + 33258.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467079588.384027
# [028]  dy_i = 88.68 * x + 33314.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467040837.583593
# [029]  dy_i = 88.64 * x + 33369.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1467003639.272143
# [030]  dy_i = 88.61 * x + 33423.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1466967931.252061
# [031]  dy_i = 88.57 * x + 33476.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1466933653.817350
